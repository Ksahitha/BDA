# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import EarlyStopping

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Define EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,  # Number of epochs with no improvement after which training will be stopped
                               restore_best_weights=True)  # Restores model to best weights with the lowest validation loss

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=100,  # Set a high number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[early_stopping])  # Add the early stopping callback
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.4328 - val_loss: 0.2323
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2268 - val_loss: 0.2057
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2008 - val_loss: 0.1875
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1855 - val_loss: 0.1763
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1760 - val_loss: 0.1681
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1677 - val_loss: 0.1619
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1622 - val_loss: 0.1556
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1563 - val_loss: 0.1529
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1543 - val_loss: 0.1518
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1528 - val_loss: 0.1503
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1515 - val_loss: 0.1487
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1501 - val_loss: 0.1475
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1491 - val_loss: 0.1464
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1478 - val_loss: 0.1456
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1473 - val_loss: 0.1450
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1462 - val_loss: 0.1445
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1459 - val_loss: 0.1441
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1453 - val_loss: 0.1434
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1451 - val_loss: 0.1429
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1444 - val_loss: 0.1420
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1435 - val_loss: 0.1412
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1430 - val_loss: 0.1405
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1420 - val_loss: 0.1398
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1411 - val_loss: 0.1391
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1404 - val_loss: 0.1386
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1400 - val_loss: 0.1382
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1397 - val_loss: 0.1381
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1393 - val_loss: 0.1377
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.1392 - val_loss: 0.1375
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1388 - val_loss: 0.1372
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1384 - val_loss: 0.1371
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1387 - val_loss: 0.1367
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1380 - val_loss: 0.1363
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1379 - val_loss: 0.1361
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1373 - val_loss: 0.1359
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1372 - val_loss: 0.1355
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1372 - val_loss: 0.1353
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1370 - val_loss: 0.1352
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1365 - val_loss: 0.1350
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1368 - val_loss: 0.1349
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1365 - val_loss: 0.1348
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1362 - val_loss: 0.1347
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1362 - val_loss: 0.1346
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1363 - val_loss: 0.1345
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1361 - val_loss: 0.1344
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1359 - val_loss: 0.1343
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1356 - val_loss: 0.1342
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1356 - val_loss: 0.1341
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1354 - val_loss: 0.1340
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1356 - val_loss: 0.1339
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1353 - val_loss: 0.1340
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1356 - val_loss: 0.1338
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1355 - val_loss: 0.1337
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1352 - val_loss: 0.1337
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1351 - val_loss: 0.1336
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1353 - val_loss: 0.1336
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1350 - val_loss: 0.1335
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1348 - val_loss: 0.1335
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1349 - val_loss: 0.1333
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1346 - val_loss: 0.1332
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1349 - val_loss: 0.1332
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1345 - val_loss: 0.1332
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1347 - val_loss: 0.1331
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1345 - val_loss: 0.1331
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1348 - val_loss: 0.1331
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1344 - val_loss: 0.1329
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1343 - val_loss: 0.1328
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1340 - val_loss: 0.1328
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1343 - val_loss: 0.1327
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1342 - val_loss: 0.1327
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1340 - val_loss: 0.1327
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1342 - val_loss: 0.1326
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1339 - val_loss: 0.1326
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1338 - val_loss: 0.1325
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1340 - val_loss: 0.1324
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1340 - val_loss: 0.1325
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1340 - val_loss: 0.1324
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1338 - val_loss: 0.1324
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1333 - val_loss: 0.1323
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1341 - val_loss: 0.1323
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1335 - val_loss: 0.1323
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1337 - val_loss: 0.1323
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1334 - val_loss: 0.1323
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1336 - val_loss: 0.1322
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1341 - val_loss: 0.1321
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1335 - val_loss: 0.1322
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1337 - val_loss: 0.1321
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1336 - val_loss: 0.1321
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1334 - val_loss: 0.1320
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1336 - val_loss: 0.1320
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1334 - val_loss: 0.1319
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1337 - val_loss: 0.1319
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1335 - val_loss: 0.1318
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1334 - val_loss: 0.1319
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1335 - val_loss: 0.1318
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1329 - val_loss: 0.1318
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1334 - val_loss: 0.1319
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1330 - val_loss: 0.1318
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1332 - val_loss: 0.1317
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1333 - val_loss: 0.1318

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import TerminateOnNaN

# Define the TerminateOnNaN callback
terminate_on_nan = TerminateOnNaN()

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Set the number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[terminate_on_nan])  # Add the TerminateOnNaN callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.4392 - val_loss: 0.2332
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.2256 - val_loss: 0.2084
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2072 - val_loss: 0.2004
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1989 - val_loss: 0.1893
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1884 - val_loss: 0.1832
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1828 - val_loss: 0.1778
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1777 - val_loss: 0.1735
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1740 - val_loss: 0.1705
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1703 - val_loss: 0.1658
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1664 - val_loss: 0.1613
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1619 - val_loss: 0.1594
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1605 - val_loss: 0.1583
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1587 - val_loss: 0.1550
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1563 - val_loss: 0.1541
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1555 - val_loss: 0.1535
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1545 - val_loss: 0.1530
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1543 - val_loss: 0.1526
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1539 - val_loss: 0.1522
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1535 - val_loss: 0.1520
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1529 - val_loss: 0.1517
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1531 - val_loss: 0.1516
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1534 - val_loss: 0.1513
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1527 - val_loss: 0.1512
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1525 - val_loss: 0.1511
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1526 - val_loss: 0.1510
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1522 - val_loss: 0.1508
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1522 - val_loss: 0.1506
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1518 - val_loss: 0.1505
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1519 - val_loss: 0.1506
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1519 - val_loss: 0.1503

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras',  # File path to save the model
                             monitor='val_loss',  # Metric to monitor
                             save_best_only=True,  # Save only the best model (based on the monitored metric)
                             mode='min',  # Minimize the monitored metric (e.g., validation loss)
                             save_weights_only=False,  # Save the entire model (set to True to save only weights)
                             verbose=1)  # Print a message when saving the model


# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),  # Validation data
                callbacks=[checkpoint])  # Add the ModelCheckpoint callback
# Out:
# Epoch 1/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4361
# Epoch 1: val_loss improved from inf to 0.24211, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.4347 - val_loss: 0.2421
# Epoch 2/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2290
# Epoch 2: val_loss improved from 0.24211 to 0.19549, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2286 - val_loss: 0.1955
# Epoch 3/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1921
# Epoch 3: val_loss improved from 0.19549 to 0.17904, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1920 - val_loss: 0.1790
# Epoch 4/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1790
# Epoch 4: val_loss improved from 0.17904 to 0.17179, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1790 - val_loss: 0.1718
# Epoch 5/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1714
# Epoch 5: val_loss improved from 0.17179 to 0.16475, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1713 - val_loss: 0.1647
# Epoch 6/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1658
# Epoch 6: val_loss improved from 0.16475 to 0.16168, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1658 - val_loss: 0.1617
# Epoch 7/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1630
# Epoch 7: val_loss improved from 0.16168 to 0.15997, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1630 - val_loss: 0.1600
# Epoch 8/30
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1612
# Epoch 8: val_loss improved from 0.15997 to 0.15799, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1612 - val_loss: 0.1580
# Epoch 9/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1589
# Epoch 9: val_loss improved from 0.15799 to 0.15522, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1589 - val_loss: 0.1552
# Epoch 10/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1563
# Epoch 10: val_loss improved from 0.15522 to 0.15260, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1563 - val_loss: 0.1526
# Epoch 11/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1534
# Epoch 11: val_loss improved from 0.15260 to 0.15048, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1534 - val_loss: 0.1505
# Epoch 12/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1514
# Epoch 12: val_loss improved from 0.15048 to 0.14898, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1514 - val_loss: 0.1490
# Epoch 13/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1498
# Epoch 13: val_loss improved from 0.14898 to 0.14821, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1498 - val_loss: 0.1482
# Epoch 14/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1492
# Epoch 14: val_loss improved from 0.14821 to 0.14752, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1492 - val_loss: 0.1475
# Epoch 15/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1489
# Epoch 15: val_loss improved from 0.14752 to 0.14669, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1489 - val_loss: 0.1467
# Epoch 16/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1477
# Epoch 16: val_loss improved from 0.14669 to 0.14553, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1477 - val_loss: 0.1455
# Epoch 17/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1470
# Epoch 17: val_loss improved from 0.14553 to 0.14456, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1469 - val_loss: 0.1446
# Epoch 18/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1456
# Epoch 18: val_loss improved from 0.14456 to 0.14416, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1456 - val_loss: 0.1442
# Epoch 19/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1454
# Epoch 19: val_loss improved from 0.14416 to 0.14379, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1454 - val_loss: 0.1438
# Epoch 20/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1451
# Epoch 20: val_loss improved from 0.14379 to 0.14351, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1451 - val_loss: 0.1435
# Epoch 21/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1451
# Epoch 21: val_loss improved from 0.14351 to 0.14338, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1451 - val_loss: 0.1434
# Epoch 22/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1451
# Epoch 22: val_loss improved from 0.14338 to 0.14295, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1451 - val_loss: 0.1430
# Epoch 23/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1443
# Epoch 23: val_loss improved from 0.14295 to 0.14272, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1443 - val_loss: 0.1427
# Epoch 24/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1440
# Epoch 24: val_loss improved from 0.14272 to 0.14227, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1440 - val_loss: 0.1423
# Epoch 25/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1437
# Epoch 25: val_loss improved from 0.14227 to 0.14186, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1437 - val_loss: 0.1419
# Epoch 26/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1434
# Epoch 26: val_loss improved from 0.14186 to 0.14147, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1434 - val_loss: 0.1415
# Epoch 27/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1433
# Epoch 27: val_loss did not improve from 0.14147
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1433 - val_loss: 0.1415
# Epoch 28/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1430
# Epoch 28: val_loss improved from 0.14147 to 0.14122, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.1430 - val_loss: 0.1412
# Epoch 29/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1428
# Epoch 29: val_loss improved from 0.14122 to 0.14084, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1428 - val_loss: 0.1408
# Epoch 30/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1425
# Epoch 30: val_loss did not improve from 0.14084
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1425 - val_loss: 0.1408

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss',  # Metric to monitor
                              factor=0.5,  # Factor by which the learning rate will be reduced (new_lr = lr * factor)
                              patience=3,  # Number of epochs with no improvement after which learning rate will be reduced
                              min_lr=1e-6,  # Lower bound for the learning rate
                              verbose=1)  # Print message when the learning rate is reduced


# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
# Assuming x_train and x_test are your training and validation datasets
autoencoder.fit(x_train, x_train,  # For autoencoders, input and output are the same
                epochs=30,  # Number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),  # Validation data
                callbacks=[reduce_lr])  # Add the ReduceLROnPlateau callback
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.4250 - val_loss: 0.2309 - learning_rate: 0.0010
# Epoch 2/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2236 - val_loss: 0.1947 - learning_rate: 0.0010
# Epoch 3/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1927 - val_loss: 0.1822 - learning_rate: 0.0010
# Epoch 4/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1821 - val_loss: 0.1747 - learning_rate: 0.0010
# Epoch 5/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1741 - val_loss: 0.1656 - learning_rate: 0.0010
# Epoch 6/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1657 - val_loss: 0.1596 - learning_rate: 0.0010
# Epoch 7/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1598 - val_loss: 0.1547 - learning_rate: 0.0010
# Epoch 8/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1558 - val_loss: 0.1526 - learning_rate: 0.0010
# Epoch 9/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1540 - val_loss: 0.1511 - learning_rate: 0.0010
# Epoch 10/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1523 - val_loss: 0.1492 - learning_rate: 0.0010
# Epoch 11/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1498 - val_loss: 0.1467 - learning_rate: 0.0010
# Epoch 12/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1474 - val_loss: 0.1439 - learning_rate: 0.0010
# Epoch 13/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1448 - val_loss: 0.1421 - learning_rate: 0.0010
# Epoch 14/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1434 - val_loss: 0.1406 - learning_rate: 0.0010
# Epoch 15/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1419 - val_loss: 0.1398 - learning_rate: 0.0010
# Epoch 16/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1411 - val_loss: 0.1391 - learning_rate: 0.0010
# Epoch 17/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1404 - val_loss: 0.1385 - learning_rate: 0.0010
# Epoch 18/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1399 - val_loss: 0.1383 - learning_rate: 0.0010
# Epoch 19/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1397 - val_loss: 0.1379 - learning_rate: 0.0010
# Epoch 20/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1391 - val_loss: 0.1376 - learning_rate: 0.0010
# Epoch 21/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1394 - val_loss: 0.1376 - learning_rate: 0.0010
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1389 - val_loss: 0.1374 - learning_rate: 0.0010
# Epoch 23/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1386 - val_loss: 0.1372 - learning_rate: 0.0010
# Epoch 24/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1387 - val_loss: 0.1371 - learning_rate: 0.0010
# Epoch 25/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1385 - val_loss: 0.1369 - learning_rate: 0.0010
# Epoch 26/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1384 - val_loss: 0.1367 - learning_rate: 0.0010
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1383 - val_loss: 0.1366 - learning_rate: 0.0010
# Epoch 28/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1383 - val_loss: 0.1365 - learning_rate: 0.0010
# Epoch 29/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1381 - val_loss: 0.1364 - learning_rate: 0.0010
# Epoch 30/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1378 - val_loss: 0.1363 - learning_rate: 0.0010

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN, ReduceLROnPlateau

# EarlyStopping callback to stop training if validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# ModelCheckpoint callback to save the best model based on validation loss
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras', monitor='val_loss', save_best_only=True, verbose=1)

# TerminateOnNaN callback to stop training if the loss becomes NaN
terminate_on_nan = TerminateOnNaN()

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,   patience=3, min_lr=1e-6, verbose=1)

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to the range [0, 1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), -1))  # -1 infers the remaining dimension
x_test = x_test.reshape((len(x_test), -1))  # -1 infers the remain

# Define the dimensions of the input and the encoded representation
input_dim = x_train.shape[1]
encoding_dim = 16  # Compress to 16 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)
# Adding a layer
encoded1 = Dense(encoding_dim, activation='relu')(encoded)

# Adding a layer
decoded1 = Dense(encoding_dim, activation='relu')(encoded1)
# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(decoded1)

# Combine the encoder and decoder into an autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Training with multiple callbacks
autoencoder.fit(x_train, x_train,
                epochs=30,  # You can set a high number of epochs
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[reduce_lr, early_stopping, checkpoint, terminate_on_nan])  # Using multiple callbacks
# Out:
# Epoch 1/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4237
# Epoch 1: val_loss improved from inf to 0.24509, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.4232 - val_loss: 0.2451 - learning_rate: 0.0010
# Epoch 2/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2377
# Epoch 2: val_loss improved from 0.24509 to 0.22032, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.2376 - val_loss: 0.2203 - learning_rate: 0.0010
# Epoch 3/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2158
# Epoch 3: val_loss improved from 0.22032 to 0.19974, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2157 - val_loss: 0.1997 - learning_rate: 0.0010
# Epoch 4/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1962
# Epoch 4: val_loss improved from 0.19974 to 0.18285, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1962 - val_loss: 0.1829 - learning_rate: 0.0010
# Epoch 5/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1817
# Epoch 5: val_loss improved from 0.18285 to 0.17514, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1817 - val_loss: 0.1751 - learning_rate: 0.0010
# Epoch 6/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1749
# Epoch 6: val_loss improved from 0.17514 to 0.16928, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1749 - val_loss: 0.1693 - learning_rate: 0.0010
# Epoch 7/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1696
# Epoch 7: val_loss improved from 0.16928 to 0.16492, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1696 - val_loss: 0.1649 - learning_rate: 0.0010
# Epoch 8/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1652
# Epoch 8: val_loss improved from 0.16492 to 0.16025, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1651 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 9/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1608
# Epoch 9: val_loss improved from 0.16025 to 0.15620, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1608 - val_loss: 0.1562 - learning_rate: 0.0010
# Epoch 10/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1568
# Epoch 10: val_loss improved from 0.15620 to 0.15393, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1568 - val_loss: 0.1539 - learning_rate: 0.0010
# Epoch 11/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1552
# Epoch 11: val_loss improved from 0.15393 to 0.15302, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1552 - val_loss: 0.1530 - learning_rate: 0.0010
# Epoch 12/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1547
# Epoch 12: val_loss improved from 0.15302 to 0.15228, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1547 - val_loss: 0.1523 - learning_rate: 0.0010
# Epoch 13/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1539
# Epoch 13: val_loss improved from 0.15228 to 0.15182, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1539 - val_loss: 0.1518 - learning_rate: 0.0010
# Epoch 14/30
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1530
# Epoch 14: val_loss improved from 0.15182 to 0.15147, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1530 - val_loss: 0.1515 - learning_rate: 0.0010
# Epoch 15/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1528
# Epoch 15: val_loss improved from 0.15147 to 0.15048, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1528 - val_loss: 0.1505 - learning_rate: 0.0010
# Epoch 16/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1520
# Epoch 16: val_loss improved from 0.15048 to 0.15004, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1520 - val_loss: 0.1500 - learning_rate: 0.0010
# Epoch 17/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1514
# Epoch 17: val_loss improved from 0.15004 to 0.14938, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1514 - val_loss: 0.1494 - learning_rate: 0.0010
# Epoch 18/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1506
# Epoch 18: val_loss improved from 0.14938 to 0.14870, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.1506 - val_loss: 0.1487 - learning_rate: 0.0010
# Epoch 19/30
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1499
# Epoch 19: val_loss improved from 0.14870 to 0.14825, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.1499 - val_loss: 0.1482 - learning_rate: 0.0010
# Epoch 20/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1500
# Epoch 20: val_loss improved from 0.14825 to 0.14759, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1500 - val_loss: 0.1476 - learning_rate: 0.0010
# Epoch 21/30
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1491
# Epoch 21: val_loss improved from 0.14759 to 0.14685, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1491 - val_loss: 0.1468 - learning_rate: 0.0010
# Epoch 22/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1481
# Epoch 22: val_loss improved from 0.14685 to 0.14592, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1481 - val_loss: 0.1459 - learning_rate: 0.0010
# Epoch 23/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1471
# Epoch 23: val_loss improved from 0.14592 to 0.14517, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1471 - val_loss: 0.1452 - learning_rate: 0.0010
# Epoch 24/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1466
# Epoch 24: val_loss improved from 0.14517 to 0.14479, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1466 - val_loss: 0.1448 - learning_rate: 0.0010
# Epoch 25/30
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1460
# Epoch 25: val_loss improved from 0.14479 to 0.14470, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1460 - val_loss: 0.1447 - learning_rate: 0.0010
# Epoch 26/30
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1457
# Epoch 26: val_loss improved from 0.14470 to 0.14445, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1457 - val_loss: 0.1445 - learning_rate: 0.0010
# Epoch 27/30
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1458
# Epoch 27: val_loss improved from 0.14445 to 0.14428, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1458 - val_loss: 0.1443 - learning_rate: 0.0010
# Epoch 28/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1458
# Epoch 28: val_loss improved from 0.14428 to 0.14414, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1458 - val_loss: 0.1441 - learning_rate: 0.0010
# Epoch 29/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1454
# Epoch 29: val_loss did not improve from 0.14414
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1454 - val_loss: 0.1442 - learning_rate: 0.0010
# Epoch 30/30
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1455
# Epoch 30: val_loss improved from 0.14414 to 0.14409, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1455 - val_loss: 0.1441 - learning_rate: 0.0010

# %%
from tensorflow.keras.models import load_model

# Load the entire model
best_autoencoder = load_model('autoencoder_best.keras')

# Let's look at the encoded representations
encoded_data = best_autoencoder.predict(x_test)
print(encoded_data)
print(encoded_data.shape)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[1.64483538e-08 1.10975877e-08 3.07585424e-08 ... 8.94513619e-09
#   3.49731941e-08 1.74193104e-08]
#  [2.68281708e-12 2.92231031e-11 1.14608084e-12 ... 1.87413453e-12
#   1.56083826e-11 2.35215276e-12]
#  [1.24451766e-19 2.81275679e-21 8.90675610e-21 ... 1.63003541e-22
#   1.10593965e-17 6.16832367e-23]
#  ...
#  [7.96392195e-13 3.71499619e-12 3.52240958e-12 ... 1.91721747e-12
#   7.92532652e-13 2.35633323e-12]
#  [7.35418410e-12 4.97987138e-11 7.45816811e-11 ... 1.90720616e-11
#   4.65448999e-11 2.55047784e-12]
#  [3.65559650e-18 1.12815326e-16 6.62991837e-18 ... 9.29480934e-18
#   1.10364274e-17 1.59720098e-18]]
# (10000, 784)
